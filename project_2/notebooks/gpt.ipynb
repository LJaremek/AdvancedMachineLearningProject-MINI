# %%
import random
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier

# Wczytanie danych
x_train_path = "../data/x_train.txt"
y_train_path = "../data/y_train.txt"

x_data = np.loadtxt(x_train_path, delimiter=" ")
y_data = np.loadtxt(y_train_path, delimiter=" ")

print("X shape:", x_data.shape)
print("Y shape:", y_data.shape)

# Podział danych na zbiór treningowy i testowy
test_size = 0.2
X_train, X_test, y_train, y_test = train_test_split(
    x_data, y_data, test_size=test_size, shuffle=True
)

def get_model(model_type="random_forest"):
    if model_type == "random_forest":
        return RandomForestClassifier(n_estimators=100)
    elif model_type == "gradient_boosting":
        return GradientBoostingClassifier(n_estimators=100)
    elif model_type == "svm":
        return SVC(kernel='linear')
    elif model_type == "logistic_regression":
        return LogisticRegression(max_iter=1000)
    elif model_type == "knn":
        return KNeighborsClassifier(n_neighbors=5)
    else:
        raise ValueError(f"Unknown model type: {model_type}")

def test_model(X_train, X_test, y_train, y_test, selected_features, model_type="random_forest"):
    X_train_subset = X_train[:, selected_features]
    X_test_subset = X_test[:, selected_features]

    model = get_model(model_type)
    model.fit(X_train_subset, y_train)
    y_pred = model.predict(X_test_subset)

    num_correct = np.sum((y_test == 1) & (y_pred == 1))
    profit = num_correct * 20 - len(selected_features) * 200
    return profit

def random_column_selection(num_features, min_cols=3, max_cols=8):
    num_selected_features = random.randint(min_cols, max_cols)
    selected_features = random.sample(range(num_features), num_selected_features)
    return selected_features

def find_best_columns(X_train, X_test, y_train, y_test, iterations=100, model_type="random_forest"):
    num_features = X_train.shape[1]
    best_features = None
    best_profit = -np.inf

    for i in range(iterations):
        selected_features = random_column_selection(num_features)
        profit = test_model(X_train, X_test, y_train, y_test, selected_features, model_type)
        
        if profit > best_profit:
            best_profit = profit
            best_features = selected_features
            print()
        
        print(f"Iteration {i+1}/{iterations}, Profit: {profit}, Best Profit: {best_profit}")

    return best_features, best_profit

# Ustawienia
iterations = 1_000  # Liczba iteracji losowego wyboru kolumn
model_type = "random_forest"

# Znajdź najlepsze kolumny
best_features, best_profit = find_best_columns(X_train, X_test, y_train, y_test, iterations, model_type)

print(f"Best features: {best_features}")
print(f"Best profit: {best_profit}")
# Out:
# X shape: (5000, 500)
# Y shape: (5000,)
# Iteration 1/1000, Profit: 3240, Best Profit: 3240
# Iteration 2/1000, Profit: 3320, Best Profit: 3320
# Iteration 3/1000, Profit: 3340, Best Profit: 3340
# Iteration 4/1000, Profit: 3240, Best Profit: 3340
# Iteration 5/1000, Profit: 4020, Best Profit: 4020
# Iteration 6/1000, Profit: 4120, Best Profit: 4120
# Iteration 7/1000, Profit: 4100, Best Profit: 4120
# Iteration 8/1000, Profit: 4000, Best Profit: 4120
# Iteration 9/1000, Profit: 3920, Best Profit: 4120
# Iteration 10/1000, Profit: 4140, Best Profit: 4140
# Iteration 11/1000, Profit: 3040, Best Profit: 4140
# Iteration 12/1000, Profit: 3360, Best Profit: 4140
# Iteration 13/1000, Profit: 2920, Best Profit: 4140
# Iteration 14/1000, Profit: 3960, Best Profit: 4140
# Iteration 15/1000, Profit: 3780, Best Profit: 4140
# Iteration 16/1000, Profit: 3260, Best Profit: 4140
# Iteration 17/1000, Profit: 4320, Best Profit: 4320
# Iteration 18/1000, Profit: 4060, Best Profit: 4320
# Iteration 19/1000, Profit: 4200, Best Profit: 4320
# Iteration 20/1000, Profit: 4280, Best Profit: 4320
# Iteration 21/1000, Profit: 2940, Best Profit: 4320
# Iteration 22/1000, Profit: 2940, Best Profit: 4320
# Iteration 23/1000, Profit: 3580, Best Profit: 4320
# Iteration 24/1000, Profit: 3740, Best Profit: 4320
# Iteration 25/1000, Profit: 3980, Best Profit: 4320
# Iteration 26/1000, Profit: 4100, Best Profit: 4320
# Iteration 27/1000, Profit: 3580, Best Profit: 4320
# Iteration 28/1000, Profit: 3360, Best Profit: 4320
# Iteration 29/1000, Profit: 3220, Best Profit: 4320
# Iteration 30/1000, Profit: 3160, Best Profit: 4320
# Iteration 31/1000, Profit: 4540, Best Profit: 4540
# Iteration 32/1000, Profit: 3620, Best Profit: 4540
# Iteration 33/1000, Profit: 4140, Best Profit: 4540
# Iteration 34/1000, Profit: 3220, Best Profit: 4540
# Iteration 35/1000, Profit: 3740, Best Profit: 4540
# Iteration 36/1000, Profit: 3620, Best Profit: 4540
# Iteration 37/1000, Profit: 4160, Best Profit: 4540
# Iteration 38/1000, Profit: 3780, Best Profit: 4540
# Iteration 39/1000, Profit: 4160, Best Profit: 4540
# Iteration 40/1000, Profit: 4500, Best Profit: 4540
# Iteration 41/1000, Profit: 4140, Best Profit: 4540
# Iteration 42/1000, Profit: 4240, Best Profit: 4540
# Iteration 43/1000, Profit: 3440, Best Profit: 4540
# Iteration 44/1000, Profit: 3980, Best Profit: 4540
# Iteration 45/1000, Profit: 4060, Best Profit: 4540
# Iteration 46/1000, Profit: 4060, Best Profit: 4540
# Iteration 47/1000, Profit: 4260, Best Profit: 4540
# Iteration 48/1000, Profit: 3800, Best Profit: 4540
# Iteration 49/1000, Profit: 4380, Best Profit: 4540
# Iteration 50/1000, Profit: 4360, Best Profit: 4540
# Iteration 51/1000, Profit: 4400, Best Profit: 4540
# Iteration 52/1000, Profit: 3160, Best Profit: 4540
# Iteration 53/1000, Profit: 3820, Best Profit: 4540
# Iteration 54/1000, Profit: 3860, Best Profit: 4540
# Iteration 55/1000, Profit: 3740, Best Profit: 4540
# Iteration 56/1000, Profit: 3420, Best Profit: 4540
# Iteration 57/1000, Profit: 3860, Best Profit: 4540
# Iteration 58/1000, Profit: 3860, Best Profit: 4540
# Iteration 59/1000, Profit: 3520, Best Profit: 4540
# Iteration 60/1000, Profit: 4080, Best Profit: 4540
# Iteration 61/1000, Profit: 3660, Best Profit: 4540
# Iteration 62/1000, Profit: 3980, Best Profit: 4540
# Iteration 63/1000, Profit: 3880, Best Profit: 4540
# Iteration 64/1000, Profit: 3200, Best Profit: 4540
# Iteration 65/1000, Profit: 3340, Best Profit: 4540
# Iteration 66/1000, Profit: 4220, Best Profit: 4540
# Iteration 67/1000, Profit: 3560, Best Profit: 4540
# Iteration 68/1000, Profit: 4140, Best Profit: 4540
# Iteration 69/1000, Profit: 4020, Best Profit: 4540
# Iteration 70/1000, Profit: 3260, Best Profit: 4540
# Iteration 71/1000, Profit: 4380, Best Profit: 4540
# Iteration 72/1000, Profit: 3040, Best Profit: 4540
# Iteration 73/1000, Profit: 3440, Best Profit: 4540
# Iteration 74/1000, Profit: 4380, Best Profit: 4540
# Iteration 75/1000, Profit: 4100, Best Profit: 4540
# Iteration 76/1000, Profit: 3940, Best Profit: 4540
# Iteration 77/1000, Profit: 3400, Best Profit: 4540
# Iteration 78/1000, Profit: 4040, Best Profit: 4540
# Iteration 79/1000, Profit: 4120, Best Profit: 4540
# Iteration 80/1000, Profit: 4060, Best Profit: 4540
# Iteration 81/1000, Profit: 3500, Best Profit: 4540
# Iteration 82/1000, Profit: 3840, Best Profit: 4540
# Iteration 83/1000, Profit: 3900, Best Profit: 4540
# Iteration 84/1000, Profit: 3840, Best Profit: 4540
# Iteration 85/1000, Profit: 3080, Best Profit: 4540
# Iteration 86/1000, Profit: 3960, Best Profit: 4540
# Iteration 87/1000, Profit: 4060, Best Profit: 4540
# Iteration 88/1000, Profit: 3900, Best Profit: 4540
# Iteration 89/1000, Profit: 3040, Best Profit: 4540
# Iteration 90/1000, Profit: 3720, Best Profit: 4540
# Iteration 91/1000, Profit: 3280, Best Profit: 4540
# Iteration 92/1000, Profit: 3000, Best Profit: 4540
# Iteration 93/1000, Profit: 4360, Best Profit: 4540
# Iteration 94/1000, Profit: 4440, Best Profit: 4540
# Iteration 95/1000, Profit: 4620, Best Profit: 4620
# Iteration 96/1000, Profit: 3540, Best Profit: 4620
# Iteration 97/1000, Profit: 3660, Best Profit: 4620
# Iteration 98/1000, Profit: 4260, Best Profit: 4620
# Iteration 99/1000, Profit: 3660, Best Profit: 4620
# Iteration 100/1000, Profit: 3700, Best Profit: 4620
# Iteration 101/1000, Profit: 4400, Best Profit: 4620
# Iteration 102/1000, Profit: 3860, Best Profit: 4620
# Iteration 103/1000, Profit: 4360, Best Profit: 4620
# Iteration 104/1000, Profit: 3780, Best Profit: 4620
# Iteration 105/1000, Profit: 4300, Best Profit: 4620
# Iteration 106/1000, Profit: 3060, Best Profit: 4620
# Iteration 107/1000, Profit: 3740, Best Profit: 4620
# Iteration 108/1000, Profit: 3760, Best Profit: 4620
# Iteration 109/1000, Profit: 4200, Best Profit: 4620
# Iteration 110/1000, Profit: 3320, Best Profit: 4620
# Iteration 111/1000, Profit: 3300, Best Profit: 4620
# Iteration 112/1000, Profit: 3820, Best Profit: 4620
# Iteration 113/1000, Profit: 4100, Best Profit: 4620
# Iteration 114/1000, Profit: 3760, Best Profit: 4620
# Iteration 115/1000, Profit: 2980, Best Profit: 4620
# Iteration 116/1000, Profit: 4600, Best Profit: 4620
# Iteration 117/1000, Profit: 3280, Best Profit: 4620
# Iteration 118/1000, Profit: 3820, Best Profit: 4620
# Iteration 119/1000, Profit: 3700, Best Profit: 4620
# Iteration 120/1000, Profit: 4480, Best Profit: 4620
# Iteration 121/1000, Profit: 3760, Best Profit: 4620
# Iteration 122/1000, Profit: 3240, Best Profit: 4620
# Iteration 123/1000, Profit: 3620, Best Profit: 4620
# Iteration 124/1000, Profit: 2920, Best Profit: 4620
# Iteration 125/1000, Profit: 3480, Best Profit: 4620
# Iteration 126/1000, Profit: 4360, Best Profit: 4620
# Iteration 127/1000, Profit: 4240, Best Profit: 4620
# Iteration 128/1000, Profit: 3240, Best Profit: 4620
# Iteration 129/1000, Profit: 4140, Best Profit: 4620
# Iteration 130/1000, Profit: 3800, Best Profit: 4620
# Iteration 131/1000, Profit: 3800, Best Profit: 4620
# Iteration 132/1000, Profit: 3240, Best Profit: 4620
# Iteration 133/1000, Profit: 4320, Best Profit: 4620
# Iteration 134/1000, Profit: 3320, Best Profit: 4620
# Iteration 135/1000, Profit: 3820, Best Profit: 4620
# Iteration 136/1000, Profit: 4640, Best Profit: 4640
# Iteration 137/1000, Profit: 4300, Best Profit: 4640
# Iteration 138/1000, Profit: 4040, Best Profit: 4640
# Iteration 139/1000, Profit: 4480, Best Profit: 4640
# Iteration 140/1000, Profit: 3460, Best Profit: 4640
# Iteration 141/1000, Profit: 3160, Best Profit: 4640
# Iteration 142/1000, Profit: 4420, Best Profit: 4640
# Iteration 143/1000, Profit: 2960, Best Profit: 4640
# Iteration 144/1000, Profit: 4160, Best Profit: 4640
# Iteration 145/1000, Profit: 2860, Best Profit: 4640
# Iteration 146/1000, Profit: 3500, Best Profit: 4640
# Iteration 147/1000, Profit: 3800, Best Profit: 4640
# Iteration 148/1000, Profit: 4040, Best Profit: 4640
# Iteration 149/1000, Profit: 3820, Best Profit: 4640
# Iteration 150/1000, Profit: 4000, Best Profit: 4640
# Iteration 151/1000, Profit: 3860, Best Profit: 4640
# Iteration 152/1000, Profit: 3940, Best Profit: 4640
# Iteration 153/1000, Profit: 4180, Best Profit: 4640
# Iteration 154/1000, Profit: 3740, Best Profit: 4640
# Iteration 155/1000, Profit: 3900, Best Profit: 4640
# Iteration 156/1000, Profit: 4100, Best Profit: 4640
# Iteration 157/1000, Profit: 3020, Best Profit: 4640
# Iteration 158/1000, Profit: 4340, Best Profit: 4640
# Iteration 159/1000, Profit: 3180, Best Profit: 4640
# Iteration 160/1000, Profit: 4520, Best Profit: 4640
# Iteration 161/1000, Profit: 3980, Best Profit: 4640
# Iteration 162/1000, Profit: 3440, Best Profit: 4640
# Iteration 163/1000, Profit: 3680, Best Profit: 4640
# Iteration 164/1000, Profit: 3120, Best Profit: 4640
# Iteration 165/1000, Profit: 4040, Best Profit: 4640
# Iteration 166/1000, Profit: 4300, Best Profit: 4640
# Iteration 167/1000, Profit: 4040, Best Profit: 4640
